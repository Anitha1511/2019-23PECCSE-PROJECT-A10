# %% [markdown]
# ## DATA VISUALIZATION AND DATA ANALYSIS

# %%
import pandas as pd 
import numpy as n
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('A.csv')
df.head()
# Out:
#     pH  Temperature  Taste  Odour  Fat  Turbidity  Colour Grade
# 0  6.6           35      1      0    1          0     254  high
# 1  6.6           36      0      1    0          1     253  high
# 2  6.6           37      1      1    1          1     255  high
# 3  6.8           45      0      1    1          1     255  high
# 4  6.6           45      0      1    1          1     250  high

# %%
df.columns
# Out:
# Index(['pH', 'Temperature', 'Taste', 'Odour', 'Fat', 'Turbidity', 'Colour',
#        'Grade'],
#       dtype='object')

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
plt.hist(df['pH'],color='red')

plt.subplot(1,2,2)
plt.hist(df['Temperature'],color='blue')
# Out:
# (array([391., 459.,  58.,  48.,  18.,  46.,  22.,   0.,   0.,  17.]),
#  array([34. , 39.6, 45.2, 50.8, 56.4, 62. , 67.6, 73.2, 78.8, 84.4, 90. ]),
#  <BarContainer object of 10 artists>)

# %%
df.hist(figsize=(15,55),layout=(15,4), color='red')
plt.show()

# %%
df['Taste'].hist(figsize=(10,5),color='red')
# Out:
# <AxesSubplot:>

# %%
plt.bar(df['Odour'],df['Fat'], color='red') # scatter, plot, triplot, stackplot
# Out:
# <BarContainer object of 1059 artists>

# %%
plt.boxplot(df['Turbidity'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x13a1eb5b070>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x13a1eb5b610>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x13a1eb60d60>],
#  'medians': [<matplotlib.lines.Line2D at 0x13a1eb5bbb0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x13a1eb5be80>],
#  'means': []}

# %%
df['Colour'].plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.displot(df['Grade'], color='red') 
# barplot, boxenplot, boxplot, countplot, displot, distplot, ecdfplot, histplot, kdeplot, pointplot, violinplot, stripplot

# %%
sns.residplot(df['pH'],df['Temperature'], color='red') # residplot, scatterplot
# Out:
# C:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='pH', ylabel='Temperature'>

# %%
sns.pairplot(df)

# %%
fig, ax = plt.subplots(figsize=(20,15))
sns.heatmap(df.corr(),annot = True, fmt='0.2%',cmap = 'autumn',ax=ax)
# Out:
# <AxesSubplot:>

# %%
def plot(df, variable):
    dataframe_pie = df[variable].value_counts()
    ax = dataframe_pie.plot.pie(figsize=(9,9), autopct='%1.2f%%', fontsize = 10)
    ax.set_title(variable + ' \n', fontsize = 10)
    return n.round(dataframe_pie/df.shape[0]*100,2)

plot(df, 'Grade')
# Out:
# low       40.51
# medium    35.32
# high      24.17
# Name: Grade, dtype: float64
